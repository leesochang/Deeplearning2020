# %% [markdown]
# <a href="https://colab.research.google.com/github/leesochang/Deeplearning2020/blob/master/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EA%B0%9C%EB%A1%A0_hello_xor_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
import numpy as np

# %%
x_data = [[0, 0],
          [0, 1],
          [1, 0],
          [1, 1]]
y_data = [[0],
          [1],
          [1],
          [0]]
x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

# %%
model = Sequential()
model.add(Dense(2, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(2))
model.add(Activation('tanh'))
model.add(Dense(2))
model.add(Activation('tanh'))
model.add(Dense(2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 2)                 6
# _________________________________________________________________
# activation_4 (Activation)    (None, 2)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 6
# _________________________________________________________________
# activation_5 (Activation)    (None, 2)                 0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 6
# _________________________________________________________________
# activation_6 (Activation)    (None, 2)                 0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 6
# ...

# %%
from keras.utils import plot_model
plot_model(model, to_file='model_xor.png', show_shapes=True)

# %%
model.fit(x_data, y_data, batch_size=1, nb_epoch=1000)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# Epoch 1/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7563
# Epoch 2/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7527
# Epoch 3/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7498
# Epoch 4/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7422
# Epoch 5/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7480
# Epoch 6/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7453
# Epoch 7/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7433
# Epoch 8/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7418
# Epoch 9/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7403
# Epoch 10/1000
# ...

# %%
hypothesis = model.predict_proba(x_data)
print(hypothesis)
# Out:
# [[0.00209685]
#  [0.99884796]
#  [0.9995845 ]
#  [0.00205394]]

# %%
predicted = hypothesis > 0.5
print(predicted)
# Out:
# [[False]
#  [ True]
#  [ True]
#  [False]]
